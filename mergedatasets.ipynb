# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

        #read data set 1 and name it df
df = pd.read_csv ('../input/globalmobility/Global_Mobility_Report -filtered.csv')
print(df)
#read data set 2 and name it df2
df2 = pd.read_csv ('../input/owid-covid/owid-covid-data2.csv')
print(df)
#merge df and df2 usiong method "outer" so that no data is ommitted from any of the 2 data frames
df3= pd.merge(left=df, right=df2, on="date", how="outer")
print(df3)
#Export the merged data frame to a csv file
df3.to_csv('mergedDataFrame.csv',index=False)
# Out:
# /kaggle/input/owid-covid/owid-covid-data2.csv
# /kaggle/input/globalmobility/Global_Mobility_Report -filtered.csv
#     country_region_code        country_region  sub_region_1  sub_region_2  \
# 0                    AE  United Arab Emirates           NaN           NaN
# 1                    AE  United Arab Emirates           NaN           NaN
# 2                    AE  United Arab Emirates           NaN           NaN
# 3                    AE  United Arab Emirates           NaN           NaN
# 4                    AE  United Arab Emirates           NaN           NaN
# ..                  ...                   ...           ...           ...
# 697                  AE  United Arab Emirates           NaN           NaN
# 698                  AE  United Arab Emirates           NaN           NaN
# 699                  AE  United Arab Emirates           NaN           NaN
# 700                  AE  United Arab Emirates           NaN           NaN
# 701                  AE  United Arab Emirates           NaN           NaN
#
#      metro_area  iso_3166_2_code  census_fips_code  \
# 0           NaN              NaN               NaN
# 1           NaN              NaN               NaN
# 2           NaN              NaN               NaN
# 3           NaN              NaN               NaN
# 4           NaN              NaN               NaN
# ..          ...              ...               ...
# 697         NaN              NaN               NaN
# 698         NaN              NaN               NaN
# 699         NaN              NaN               NaN
# 700         NaN              NaN               NaN
# 701         NaN              NaN               NaN
#
#                         place_id        date  \
# 0    ChIJvRKrsd9IXj4RpwoIwFYv0zM  15/02/2020
# 1    ChIJvRKrsd9IXj4RpwoIwFYv0zM  16/02/2020
# 2    ChIJvRKrsd9IXj4RpwoIwFYv0zM  17/02/2020
# 3    ChIJvRKrsd9IXj4RpwoIwFYv0zM  18/02/2020
# 4    ChIJvRKrsd9IXj4RpwoIwFYv0zM  19/02/2020
# ..                           ...         ...
# 697  ChIJvRKrsd9IXj4RpwoIwFYv0zM   12/1/2022
# 698  ChIJvRKrsd9IXj4RpwoIwFYv0zM  13/01/2022
# 699  ChIJvRKrsd9IXj4RpwoIwFYv0zM  14/01/2022
# 700  ChIJvRKrsd9IXj4RpwoIwFYv0zM  15/01/2022
# 701  ChIJvRKrsd9IXj4RpwoIwFYv0zM  16/01/2022
#
#      retail_and_recreation_percent_change_from_baseline  \
# 0                                                    0
# 1                                                    1
# 2                                                   -1
# 3                                                   -2
# 4                                                   -2
# ..                                                 ...
# 697                                                 10
# 698                                                  2
# 699                                                  4
# 700                                                 15
# 701                                                 20
#
#      grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                    4
# 1                                                    4
# 2                                                    1
# 3                                                    1
# 4                                                    0
# ..                                                 ...
# 697                                                 43
# 698                                                 33
# 699                                                 31
# 700                                                 43
# 701                                                 55
#
#      parks_percent_change_from_baseline  \
# 0                                     5
# 1                                     4
# 2                                     5
# 3                                     5
# 4                                     4
# ..                                  ...
# 697                                  -6
# 698                                 -11
# 699                                 -15
# 700                                  12
# 701                                   9
#
#      transit_stations_percent_change_from_baseline  \
# 0                                                0
# 1                                                1
# 2                                                1
# 3                                                0
# 4                                               -1
# ..                                             ...
# 697                                             -3
# 698                                             -6
# 699                                              9
# 700                                              1
# 701                                            -13
#
#      workplaces_percent_change_from_baseline  \
# 0                                          2
# 1                                          2
# 2                                          2
# 3                                          2
# 4                                          2
# ..                                       ...
# 697                                       -6
# 698                                       -5
# 699                                      144
# 700                                       -4
# 701                                      -48
#
#      residential_percent_change_from_baseline
# 0                                           1
# 1                                           1
# 2                                           1
# 3                                           1
# 4                                           1
# ..                                        ...
# 697                                        10
# 698                                        12
# 699                                        -2
# 700                                         6
# 701                                        18
#
# [702 rows x 15 columns]
#     country_region_code        country_region  sub_region_1  sub_region_2  \
# 0                    AE  United Arab Emirates           NaN           NaN
# 1                    AE  United Arab Emirates           NaN           NaN
# 2                    AE  United Arab Emirates           NaN           NaN
# 3                    AE  United Arab Emirates           NaN           NaN
# 4                    AE  United Arab Emirates           NaN           NaN
# ..                  ...                   ...           ...           ...
# 697                  AE  United Arab Emirates           NaN           NaN
# 698                  AE  United Arab Emirates           NaN           NaN
# 699                  AE  United Arab Emirates           NaN           NaN
# 700                  AE  United Arab Emirates           NaN           NaN
# 701                  AE  United Arab Emirates           NaN           NaN
#
#      metro_area  iso_3166_2_code  census_fips_code  \
# 0           NaN              NaN               NaN
# 1           NaN              NaN               NaN
# 2           NaN              NaN               NaN
# 3           NaN              NaN               NaN
# 4           NaN              NaN               NaN
# ..          ...              ...               ...
# 697         NaN              NaN               NaN
# 698         NaN              NaN               NaN
# 699         NaN              NaN               NaN
# 700         NaN              NaN               NaN
# 701         NaN              NaN               NaN
#
#                         place_id        date  \
# 0    ChIJvRKrsd9IXj4RpwoIwFYv0zM  15/02/2020
# 1    ChIJvRKrsd9IXj4RpwoIwFYv0zM  16/02/2020
# 2    ChIJvRKrsd9IXj4RpwoIwFYv0zM  17/02/2020
# 3    ChIJvRKrsd9IXj4RpwoIwFYv0zM  18/02/2020
# 4    ChIJvRKrsd9IXj4RpwoIwFYv0zM  19/02/2020
# ..                           ...         ...
# 697  ChIJvRKrsd9IXj4RpwoIwFYv0zM   12/1/2022
# 698  ChIJvRKrsd9IXj4RpwoIwFYv0zM  13/01/2022
# 699  ChIJvRKrsd9IXj4RpwoIwFYv0zM  14/01/2022
# 700  ChIJvRKrsd9IXj4RpwoIwFYv0zM  15/01/2022
# 701  ChIJvRKrsd9IXj4RpwoIwFYv0zM  16/01/2022
#
#      retail_and_recreation_percent_change_from_baseline  \
# 0                                                    0
# 1                                                    1
# 2                                                   -1
# 3                                                   -2
# 4                                                   -2
# ..                                                 ...
# 697                                                 10
# 698                                                  2
# 699                                                  4
# 700                                                 15
# 701                                                 20
#
#      grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                    4
# 1                                                    4
# 2                                                    1
# 3                                                    1
# 4                                                    0
# ..                                                 ...
# 697                                                 43
# 698                                                 33
# 699                                                 31
# 700                                                 43
# 701                                                 55
#
#      parks_percent_change_from_baseline  \
# 0                                     5
# 1                                     4
# 2                                     5
# 3                                     5
# 4                                     4
# ..                                  ...
# 697                                  -6
# 698                                 -11
# 699                                 -15
# 700                                  12
# 701                                   9
#
#      transit_stations_percent_change_from_baseline  \
# 0                                                0
# 1                                                1
# 2                                                1
# 3                                                0
# 4                                               -1
# ..                                             ...
# 697                                             -3
# 698                                             -6
# 699                                              9
# 700                                              1
# 701                                            -13
#
#      workplaces_percent_change_from_baseline  \
# 0                                          2
# 1                                          2
# 2                                          2
# 3                                          2
# 4                                          2
# ..                                       ...
# 697                                       -6
# 698                                       -5
# 699                                      144
# 700                                       -4
# 701                                      -48
#
#      residential_percent_change_from_baseline
# 0                                           1
# 1                                           1
# 2                                           1
# 3                                           1
# 4                                           1
# ..                                        ...
# 697                                        10
# 698                                        12
# 699                                        -2
# 700                                         6
# 701                                        18
#
# [702 rows x 15 columns]
#     country_region_code        country_region  sub_region_1  sub_region_2  \
# 0                    AE  United Arab Emirates           NaN           NaN
# 1                    AE  United Arab Emirates           NaN           NaN
# 2                    AE  United Arab Emirates           NaN           NaN
# 3                    AE  United Arab Emirates           NaN           NaN
# 4                    AE  United Arab Emirates           NaN           NaN
# ..                  ...                   ...           ...           ...
# 716                 NaN                   NaN           NaN           NaN
# 717                 NaN                   NaN           NaN           NaN
# 718                 NaN                   NaN           NaN           NaN
# 719                 NaN                   NaN           NaN           NaN
# 720                 NaN                   NaN           NaN           NaN
#
#      metro_area  iso_3166_2_code  census_fips_code  \
# 0           NaN              NaN               NaN
# 1           NaN              NaN               NaN
# 2           NaN              NaN               NaN
# 3           NaN              NaN               NaN
# 4           NaN              NaN               NaN
# ..          ...              ...               ...
# 716         NaN              NaN               NaN
# 717         NaN              NaN               NaN
# 718         NaN              NaN               NaN
# 719         NaN              NaN               NaN
# 720         NaN              NaN               NaN
#
#                         place_id        date  \
# 0    ChIJvRKrsd9IXj4RpwoIwFYv0zM  15/02/2020
# 1    ChIJvRKrsd9IXj4RpwoIwFYv0zM  16/02/2020
# 2    ChIJvRKrsd9IXj4RpwoIwFYv0zM  17/02/2020
# 3    ChIJvRKrsd9IXj4RpwoIwFYv0zM  18/02/2020
# 4    ChIJvRKrsd9IXj4RpwoIwFYv0zM  19/02/2020
# ..                           ...         ...
# 716                          NaN   12/2/2020
# 717                          NaN  13/02/2020
# 718                          NaN  14/02/2020
# 719                          NaN  17/01/2022
# 720                          NaN  18/01/2022
#
#      retail_and_recreation_percent_change_from_baseline  ...  Unnamed: 16374  \
# 0                                                  0.0   ...             NaN
# 1                                                  1.0   ...             NaN
# 2                                                 -1.0   ...             NaN
# 3                                                 -2.0   ...             NaN
# 4                                                 -2.0   ...             NaN
# ..                                                 ...   ...             ...
# 716                                                NaN   ...             NaN
# 717                                                NaN   ...             NaN
# 718                                                NaN   ...             NaN
# 719                                                NaN   ...             NaN
# 720                                                NaN   ...             NaN
#
#      Unnamed: 16375  Unnamed: 16376  Unnamed: 16377  Unnamed: 16378  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 716             NaN             NaN             NaN             NaN
# 717             NaN             NaN             NaN             NaN
# 718             NaN             NaN             NaN             NaN
# 719             NaN             NaN             NaN             NaN
# 720             NaN             NaN             NaN             NaN
#
#     Unnamed: 16379 Unnamed: 16380 Unnamed: 16381  Unnamed: 16382  \
# 0              NaN            NaN            NaN             NaN
# 1              NaN            NaN            NaN             NaN
# 2              NaN            NaN            NaN             NaN
# 3              NaN            NaN            NaN             NaN
# 4              NaN            NaN            NaN             NaN
# ..             ...            ...            ...             ...
# 716            NaN            NaN            NaN             NaN
# 717            NaN            NaN            NaN             NaN
# 718            NaN            NaN            NaN             NaN
# 719            NaN            NaN            NaN             NaN
# 720            NaN            NaN            NaN             NaN
#
#      Unnamed: 16383
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 716             NaN
# 717             NaN
# 718             NaN
# 719             NaN
# 720             NaN
#
# [721 rows x 16398 columns]
